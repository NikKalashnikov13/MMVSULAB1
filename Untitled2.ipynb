# %% [markdown]
# <a href="https://colab.research.google.com/github/NikKalashnikov13/MMVSULAB1/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторная №4

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
# Определяем функцию для параметров ДУ
def dxdt(x,t):
    k=-0.3
    return k*x
t=np.linspace(0, 100 , 100)
# Решаем ДУ 
solve_1=odeint(dxdt,y0=1,t=t)
solve_1=solve_1.flatten()
# Находим функцию, задащую параметры ДУ для решения методом Эйлера
def euler(f, y0=1, h=0.01, n = 100):
    eul = np.arange(0,n+h,h)
    y = [y0]
    for i in range(len(eul)-1):
        y.append(y[i] + h*f(y[i],eul[i]))
    return y, eul
solve_2, eul = euler(dxdt)
# Строим график решения ДУ методом Эйлера
# %matplotlib inline
plt.plot(t, solve_1, label=r"x'=kx", color = "blue")
plt.plot(eul, solve_2, label = r"Метод Эйлера", color = "red")
plt.grid(True)
plt.legend()
plt.show()
